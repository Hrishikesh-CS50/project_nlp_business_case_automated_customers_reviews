# %% [markdown]
# # Product Review Summarization using ChatGPT API
# ## Generate Meta-Reviews for Top 3 Products in Each Category
#
# This notebook uses ChatGPT (OpenAI API) to generate comprehensive meta-reviews by:
# 1. Aggregating reviews for top 3 products in each category
# 2. Generating summary articles with key insights
# 3. Identifying top complaints and product recommendations
#
# ### Requirements:
# - OpenAI API key (GPT-4 or GPT-3.5-turbo)
# - Input: `product_summary_data.json` (from ranking notebook)
# - Output: Blog-style articles for each category

# %% [markdown]
# ## 1. Installation

# %%
# python -m pip install openai

# %% [markdown]
# ## 2. Import Libraries

# %%
import json
import os
from openai import OpenAI
from dotenv import load_dotenv
from datetime import datetime
import time
from pathlib import Path

# %% [markdown]
# ## 3. Configure OpenAI API Key
#
# **Choose ONE method:**
#
# ### Method A: Direct Input (Quick for Testing)

# %%
# Resolve project root (one level above notebooks/)
project_root = Path().resolve().parent

# Load .env explicitly
load_dotenv(project_root / ".env")

# Fetch API key
api_key = os.getenv("OPENAI_API_KEY")

if not api_key:
    raise ValueError("OPENAI_API_KEY not found in .env")

print("API key loaded successfully")

# Initialize OpenAI client
client = OpenAI(api_key=api_key)

print("OpenAI client initialized")
# Out:
# API key loaded successfully
# OpenAI client initialized

# %% [markdown]
# ## 4. Load Product Summary Data

# %%
import json

with open('../datasets/processed/product_summary_data.json',
          'r',
          encoding='utf-8') as f:
    summary_data = json.load(f)

print(f"✓ Loaded data for {len(summary_data)} categories")
print("\nCategories:")

for cat_data in summary_data:
    category = cat_data['category']
    n_products = len(cat_data.get('top_products',
                                  cat_data.get('top_3_products', [])))
    print(f"  - {category}: {n_products} products")
# Out:
# ✓ Loaded data for 5 categories
#
# Categories:
#   - Computers and electronics: 3 products
#   - Amazon devices & accessories: 3 products
#   - Entertainment Appliances: 3 products
#   - Kids Toys & kids entertainment: 3 products
#   - Batteries and household essentials: 2 products

# %% [markdown]
# ## 5. Helper Functions for Prompt Generation

# %%
def format_product_info(product, rank):
    """
    Format product information for the prompt.
    """
    info = f"""
Product {rank}: {product['name']}
- Average Rating: {product['avg_rating']}/5.0
- Total Reviews: {product['total_reviews']:,}
- Quality Score: {product['quality_score']:.2f}/5.0
- Sentiment Distribution: {product['positive_pct']:.1f}% positive, {product['negative_pct']:.1f}% negative, {product['neutral_pct']:.1f}% neutral
"""
    
    # Add sample positive reviews
    if product.get('positive_reviews'):
        info += "\nPositive Review Examples:\n"
        for i, review in enumerate(product['positive_reviews'][:3], 1):
            info += f"  {i}. \"{review}\"\n"
    
    # Add sample negative reviews
    if product.get('negative_reviews'):
        info += "\nNegative Review Examples:\n"
        for i, review in enumerate(product['negative_reviews'][:3], 1):
            info += f"  {i}. \"{review}\"\n"
    
    return info


def format_worst_product_info(product):
    """
    Format worst product information for the prompt.
    """
    info = f"""
Product to Avoid: {product['name']}
- Average Rating: {product['avg_rating']}/5.0
- Total Reviews: {product['total_reviews']:,}
- Quality Score: {product['quality_score']:.2f}/5.0
- Negative Reviews: {product['negative_pct']:.1f}%
"""
    
    if product.get('negative_reviews'):
        info += "\nCommon Complaints:\n"
        for i, review in enumerate(product['negative_reviews'][:5], 1):
            info += f"  {i}. \"{review}\"\n"
    
    return info


def create_summarization_prompt(category_data):
    """
    Create a comprehensive prompt for ChatGPT to generate a meta-review.
    """
    category = category_data['category']
    top_products = category_data.get('top_products', category_data.get('top_3_products', []))
    worst_product = category_data.get('worst_product')
    
    # Handle category metadata if present
    metadata = category_data.get('category_metadata', {})
    total_products = metadata.get('total_products', len(top_products))
    top_label = metadata.get('top_label', f'Top {len(top_products)}')
    
    prompt = f"""You are a professional product reviewer writing for a consumer electronics blog. Write a comprehensive, engaging article about products in the {category} category on Amazon.

# Article Requirements:
1. Write in a conversational, helpful tone (like Wirecutter or The Verge)
2. Be specific and cite actual review examples
3. Compare and contrast the products clearly
4. Provide actionable recommendations
5. Length: 600-800 words

# Structure:
## Introduction
- Brief overview of the {category} category
- Why these products matter to consumers

## {top_label}
"""
    
    # Add each product
    for i, product in enumerate(top_products, 1):
        prompt += format_product_info(product, i)
        prompt += "\n"
    
    prompt += """
### For Each Product:
- Summarize what customers love (based on positive reviews)
- Highlight key features and strengths
- Mention common complaints (based on negative reviews)
- Who should buy this product?

## Key Differences
- Create a clear comparison highlighting what makes each product unique
- Help readers choose based on their needs

## Common Issues Across Products
- Aggregate the top complaints mentioned in negative reviews
- Provide context and severity of each issue
"""
    
    # Add worst product if present
    if worst_product:
        prompt += "\n## Product to Avoid\n"
        prompt += format_worst_product_info(worst_product)
        prompt += "\n- Explain why this product underperforms based on the complaints\n"
    else:
        prompt += "\n## Note"
        if total_products <= 3:
            prompt += f"\n- This category has limited options ({total_products} products)\n"
            prompt += "- All available products are included above\n"
        else:
            prompt += "\n- All products in this category perform reasonably well\n"
    
    prompt += """
## Final Recommendation
- Provide a clear "best overall" pick
- Suggest "best value" or "best for specific use case" alternatives
- End with a confident recommendation

# Writing Guidelines:
- Use direct quotes from actual reviews (provided above)
- Be balanced - mention both pros and cons
- Use headers and bullet points for readability
- Write product names in bold on first mention
- Include specific numbers (ratings, review counts) to build credibility
- Avoid marketing language - be honest and helpful
"""
    
    return prompt

print("✓ Helper functions defined")
# Out:
# ✓ Helper functions defined

# %% [markdown]
# ## 6. Test Prompt Generation (Optional)

# %%
# Preview the prompt for the first category
test_prompt = create_summarization_prompt(summary_data[0])

print("="*100)
print("SAMPLE PROMPT FOR FIRST CATEGORY")
print("="*100)
print(test_prompt[:2000])  # Show first 2000 characters
print("\n... (truncated for display) ...\n")
print("="*100)
print(f"Full prompt length: {len(test_prompt)} characters")
# Out:
# ====================================================================================================
# SAMPLE PROMPT FOR FIRST CATEGORY
# ====================================================================================================
# You are a professional product reviewer writing for a consumer electronics blog. Write a comprehensive, engaging article about products in the Computers and electronics category on Amazon.
#
# # Article Requirements:
# 1. Write in a conversational, helpful tone (like Wirecutter or The Verge)
# 2. Be specific and cite actual review examples
# 3. Compare and contrast the products clearly
# 4. Provide actionable recommendations
# 5. Length: 600-800 words
#
# # Structure:
# ## Introduction
# - Brief overview of the Computers and electronics category
# - Why these products matter to consumers
#
# ## Top 3
#
# Product 1: Fire Tablet, 7 Display, Wi-Fi, 8 GB - Includes Special Offers, Black
# - Average Rating: 4.67/5.0
# - Total Reviews: 15
# - Quality Score: 1.05/5.0
# - Sentiment Distribution: 100.0% positive, 0.0% negative, 0.0% neutral
#
# Positive Review Examples:
#   1. "I initially had trouble deciding between the paperwhite and the voyage because reviews more or less said the same thing: the paperwhite is great, but if you have spending money, go for the voyage.Fortunately, I had friends who owned each, so I ended up buying the paperwhite on this basis: both models now have 300 ppi, so the 80 dollar jump turns out pricey the voyage's page press isn't always sensitive, and if you are fine with a specific setting, you don't need auto light adjustment).It's been a week and I am loving my paperwhite, no regrets! The touch screen is receptive and easy to use, and I keep the light at a specific setting regardless of the time of day. (In any case, it's not hard to change the setting either, as you'll only be changing the light level at a certain time of day, not every now and then while reading).Also glad that I went for the international shipping option with Amazon. Extra expense, but delivery was on time, with tracking, and I didnt need to worry about customs, which I may have if I used a third party shipping service."
#   2. "Allow me to preface this with a little history. I am (was) a casual reader who owned a
#
# ... (truncated for display) ...
#
# ====================================================================================================
# Full prompt length: 12324 characters

# %% [markdown]
# ## 7. Generate Summaries with ChatGPT

# %%
def generate_summary(category_data, model="gpt-3.5-turbo", temperature=0.7):
    """
    Generate a summary article for a category using ChatGPT.
    
    Args:
        category_data: Dictionary containing category and product information
        model: OpenAI model to use ("gpt-3.5-turbo" or "gpt-4" or "gpt-4-turbo")
        temperature: Creativity level (0.0-1.0, higher = more creative)
    
    Returns:
        Generated article text
    """
    category = category_data['category']
    print(f"\nGenerating summary for: {category}...")
    
    # Create the prompt
    prompt = create_summarization_prompt(category_data)
    
    try:
        # Call ChatGPT API
        response = client.chat.completions.create(
            model=model,
            messages=[
                {
                    "role": "system",
                    "content": "You are an expert product reviewer who writes honest, detailed, and helpful reviews for consumers. You analyze customer feedback to provide balanced recommendations."
                },
                {
                    "role": "user",
                    "content": prompt
                }
            ],
            temperature=temperature,
            max_tokens=2000  # Adjust based on desired article length
        )
        
        summary = response.choices[0].message.content
        
        # Get token usage info
        usage = response.usage
        print(f"  ✓ Generated ({usage.total_tokens} tokens: {usage.prompt_tokens} prompt + {usage.completion_tokens} completion)")
        
        return summary
        
    except Exception as e:
        print(f"  ✗ Error: {str(e)}")
        return f"Error generating summary for {category}: {str(e)}"


print("✓ Summary generation function defined")
# Out:
# ✓ Summary generation function defined

# %% [markdown]
# ## 8. Generate Summaries for All Categories

# %%
# Configuration
MODEL = "gpt-3.5-turbo"  # Options: "gpt-3.5-turbo" (cheapest) or "gpt-4" (best quality)
TEMPERATURE = 0.7  # 0.0 = more focused, 1.0 = more creative
DELAY_BETWEEN_CALLS = 2  # Seconds to wait between API calls (to avoid rate limits)

print("="*100)
print("GENERATING SUMMARIES FOR ALL CATEGORIES")
print("="*100)
print(f"Model: {MODEL}")
print(f"Temperature: {TEMPERATURE}")
print(f"Categories to process: {len(summary_data)}")
print()

# Store all generated summaries
generated_summaries = []

# Generate summary for each category
for i, category_data in enumerate(summary_data, 1):
    category = category_data['category']
    
    print(f"[{i}/{len(summary_data)}] Processing: {category}")
    
    # Generate the summary
    summary_text = generate_summary(
        category_data=category_data,
        model=MODEL,
        temperature=TEMPERATURE
    )
    
    # Store the result
    generated_summaries.append({
        'category': category,
        'summary': summary_text,
        'generated_at': datetime.now().isoformat(),
        'model': MODEL,
        'temperature': TEMPERATURE
    })
    
    # Wait before next API call (avoid rate limits)
    if i < len(summary_data):
        time.sleep(DELAY_BETWEEN_CALLS)

print()
print("="*100)
print(f"✓ COMPLETED: Generated {len(generated_summaries)} summaries")
print("="*100)
# Out:
# ====================================================================================================
# GENERATING SUMMARIES FOR ALL CATEGORIES
# ====================================================================================================
# Model: gpt-3.5-turbo
# Temperature: 0.7
# Categories to process: 5
#
# [1/5] Processing: Computers and electronics
#
# Generating summary for: Computers and electronics...
#   ✓ Generated (4091 tokens: 2915 prompt + 1176 completion)
# [2/5] Processing: Amazon devices & accessories
#
# Generating summary for: Amazon devices & accessories...
#   ✓ Generated (3116 tokens: 2221 prompt + 895 completion)
# [3/5] Processing: Entertainment Appliances
#
# Generating summary for: Entertainment Appliances...
#   ✓ Generated (1941 tokens: 987 prompt + 954 completion)
# [4/5] Processing: Kids Toys & kids entertainment
#
# Generating summary for: Kids Toys & kids entertainment...
#   ✓ Generated (2694 tokens: 1588 prompt + 1106 completion)
# [5/5] Processing: Batteries and household essentials
#
# Generating summary for: Batteries and household essentials...
#   ✓ Generated (2182 tokens: 1244 prompt + 938 completion)
#
# ====================================================================================================
# ✓ COMPLETED: Generated 5 summaries
# ====================================================================================================

# %% [markdown]
# ## 9. Display Generated Summaries

# %%
# Display all generated summaries
for i, summary in enumerate(generated_summaries, 1):
    print("\n" + "="*100)
    print(f"CATEGORY {i}: {summary['category'].upper()}")
    print("="*100)
    print()
    print(summary['summary'])
    print()
    print("-"*100)
    print(f"Generated: {summary['generated_at']} | Model: {summary['model']}")
    print()
# Out:
# ====================================================================================================
# CATEGORY 1: COMPUTERS AND ELECTRONICS
# ====================================================================================================
#
# ## Introduction
#
# In the vast realm of Computers and electronics, Amazon stands out as a treasure trove of innovative products that cater to a wide range of consumer needs. From cutting-edge tablets to handy document organizers and refurbished Fire TVs, the options are endless. Let's delve into the top three products in this category on Amazon, analyzing customer feedback to help you make informed purchasing decisions.
#
# ## Top 3
#
# ### **Fire Tablet, 7 Display, Wi-Fi, 8 GB - Includes Special Offers, Black**
# - **Average Rating:** 4.67/5.0
# - **Total Reviews:** 15
# - **Quality Score:** 1.05/5.0
# - **Sentiment Distribution:** 100.0% positive, 0.0% negative, 0.0% neutral
#
# #### What Customers Love:
# - Customers praise the **responsive touch screen** and **specific light settings** that enhance the reading experience.
# - The **affordable price** point compared to other models is a significant plus for many users.
# - Users appreciate the **international shipping option** provided by Amazon for timely delivery.
#
# #### Key Features and Strengths:
# - **Receptive touch screen** for easy navigation.
# - **Affordable pricing** makes it a budget-friendly option.
# - **Specific light settings** cater to individual preferences for reading comfort.
#
# #### Common Complaints:
# - Some users reported **eye strain** with the previous Fire model but haven't experienced it with the Paperwhite.
# - A few users faced challenges with the **page press sensitivity** on the Voyage model.
#
# #### Who Should Buy This Product:
# - Ideal for budget-conscious readers who appreciate a **reliable touch screen** and **customizable light settings** for an optimal reading experience.
#
# ### **Expanding Accordion File Folder Plastic Portable Document Organizer Letter Size**
# - **Average Rating:** 5.0/5.0
# - **Total Reviews:** 9
# - **Quality Score:** 1.00/5.0
# - **Sentiment Distribution:** 100.0% positive, 0.0% negative, 0.0% neutral
#
# #### What Customers Love:
# - Customers appreciate the **expandable bottom** that allows for increased storage capacity.
# - Users find it **sturdy** and **perfect for organizing projects**.
#
# #### Key Features and Strengths:
# - **Expandable bottom** for additional storage space.
# - **Sturdy construction** ensures durability for long-term use.
#
# #### Common Complaints:
# - No significant negative feedback was noted in customer reviews.
#
# #### Who Should Buy This Product:
# - Ideal for individuals seeking a **portable and durable document organizer** for projects or office work.
#
# ### **Certified Refurbished Amazon Fire TV with Alexa Voice Remote**
# - **Average Rating:** 5.0/5.0
# - **Total Reviews:** 4
# - **Quality Score:** 1.00/5.0
# - **Sentiment Distribution:** 100.0% positive, 0.0% negative, 0.0% neutral
#
# #### What Customers Love:
# - Users appreciate the **upgraded features** compared to previous versions.
# - Customers find the **Alexa Voice Remote** functionality convenient for seamless navigation.
#
# #### Key Features and Strengths:
# - **Upgraded features** provide an enhanced user experience.
# - **Alexa Voice Remote** allows for hands-free control and effortless browsing.
#
# #### Common Complaints:
# - Some users found the product **pricey** for its features.
# - A few customers encountered **technical issues** with the device.
#
# #### Who Should Buy This Product:
# - Recommended for those seeking an **upgraded media streaming experience** with added convenience of voice control.
#
# ## Key Differences
#
# In comparing the three products, the **Fire Tablet** stands out for its **affordable pricing** and **customizable light settings**, catering to avid readers on a budget. The **Document Organizer** excels in **portability** and **sturdy construction**, making it ideal for organizing projects. On the other hand, the **Certified Refurbished Fire TV** shines with its **upgraded features** and **Alexa Voice Remote**, offering a seamless media streaming experience.
#
# ## Common Issues Across Products
#
# Based on customer feedback, common complaints include:
# - **Price concerns** for some users.
# - **Technical issues** reported by a few customers.
# - **Sensitivity challenges** with certain features.
#
# It's essential to consider these factors when making a purchase decision to ensure a satisfactory experience.
#
# ## Product to Avoid
#
# ### **Oem Amazon Kindle Power Usb Adapter Wall Travel Charger Fire/dx/+micro Usb Cable**
# - **Average Rating:** 1.0/5.0
# - **Total Reviews:** 4
# - **Quality Score:** 0.08/5.0
# - **Negative Reviews:** 100.0%
#
# #### Common Complaints:
# - Users expressed dissatisfaction with the **additional purchase requirement** for a critical charging component.
# - Some customers found the **charger unnecessary** and a **waste of money** due to existing charging options.
#
# Based on customer feedback highlighting **price concerns** and the **lack of value**, it's advisable to steer clear of this product.
#
# ## Final Recommendation
#
# In conclusion, while each product offers unique features and benefits, the **Fire Tablet** emerges as the **best overall pick** for its affordability and customizable settings, catering to avid readers. For those in need of a **portable document organizer**, the **Accordion File Folder** is a reliable choice. However, for an **upgraded media streaming experience** with voice control, the **Certified Refurbished Fire TV** is a solid option.
#
# When selecting your ideal product, consider your specific needs and preferences to make a well-informed choice. Happy shopping!
#
# ----------------------------------------------------------------------------------------------------
# Generated: 2026-02-20T14:40:55.255305 | Model: gpt-3.5-turbo
#
#
# ====================================================================================================
# CATEGORY 2: AMAZON DEVICES & ACCESSORIES
# ====================================================================================================
#
# **Article Title: Unveiling the Best Amazon Devices & Accessories: A Comprehensive Review**
#
# **Introduction**
#
# Welcome to the world of Amazon devices and accessories, where technology meets convenience in the palm of your hand. These products have become integral parts of our daily lives, offering a blend of entertainment, productivity, and connectivity like never before. In this article, we will delve into the top products in this category, providing you with insights to make informed purchasing decisions.
#
# **Top 3 Products**
#
# **Product 1: Echo (Black)**
#
# - **Average Rating:** 5.0/5.0
# - **Total Reviews:** 3
# - **Quality Score:** 1.00/5.0
#
# **What Customers Love:**
# Customers rave about the Echo's voice recognition, music streaming capabilities, and overall usefulness in daily tasks.
#
# **Key Features:**
# - Excellent voice recognition
# - Seamless music playback
# - Handy for setting alarms and reminders
#
# **Common Complaints:**
# Some users expressed dissatisfaction with the search engine used and limitations in setting alarms across multiple devices.
#
# **Who Should Buy:**
# Ideal for those looking for a smart speaker with top-notch voice recognition and music streaming features.
#
# **Product 2: Certified Refurbished Amazon Echo**
#
# - **Average Rating:** 5.0/5.0
# - **Total Reviews:** 7
# - **Quality Score:** 1.00/5.0
#
# **What Customers Love:**
# Users appreciate the notifications, calendar sync, and durability of the Certified Refurbished Amazon Echo.
#
# **Key Features:**
# - Seamless integration with Google calendar
# - Sturdy build quality
# - Notifications feature
#
# **Common Complaints:**
# Few users faced challenges with messaging integration and device protection.
#
# **Who Should Buy:**
# Recommended for those seeking a reliable smart speaker with enhanced durability and calendar syncing features.
#
# **Product 3: Amazon Fire Hd 6 Standing Protective Case (4th Generation - 2014 Release, Cayenne Red)**
#
# - **Average Rating:** 4.83/5.0
# - **Total Reviews:** 6
# - **Quality Score:** 0.99/5.0
#
# **What Customers Love:**
# Users enjoy the sturdy build, easy installation, and vibrant color options of the Amazon Fire Hd 6 Standing Protective Case.
#
# **Key Features:**
# - Sturdy protection for the Fire HD 6 tablet
# - Easy to install
# - Stylish color choices
#
# **Common Complaints:**
# Some users mentioned issues with case fit or compatibility with the tablet.
#
# **Who Should Buy:**
# Perfect for Fire HD 6 tablet owners seeking reliable protection with a touch of style.
#
# **Key Differences**
#
# - **Echo vs. Certified Refurbished Echo:**
#   - Echo offers superior sound quality, while the Certified Refurbished Echo provides enhanced durability.
# - **Echo vs. Amazon Fire Hd 6 Standing Protective Case:**
#   - Echo focuses on voice recognition and music streaming, while the Fire HD 6 Case offers tablet protection and style.
#
# **Common Issues Across Products**
#
# - **Search Engine Limitations:** Some users expressed frustration with the search capabilities of the Echo devices.
# - **Compatibility Concerns:** A few customers faced compatibility issues with the protective case for the Fire HD 6 tablet.
#
# **Product to Avoid: Amazon Tap Smart Assistant Alexaenabled (black) Brand New**
#
# - **Average Rating:** 4.0/5.0
# - **Total Reviews:** 8
# - **Quality Score:** 0.84/5.0
# - **Negative Reviews:** 12.5%
#
# **Common Complaints:**
# Users reported challenges in setting up the device and unwanted product recommendations.
#
# **Why to Avoid:**
# The Amazon Tap Smart Assistant underperforms in user-friendliness and may not meet expectations in functionality.
#
# **Final Recommendation**
#
# For the best overall experience, the **Echo (Black)** stands out with its exceptional voice recognition and music streaming capabilities. If you seek a more budget-friendly option, consider the **Certified Refurbished Amazon Echo** for its durability and useful features. Lastly, if tablet protection is your priority, the **Amazon Fire Hd 6 Standing Protective Case** offers a stylish and reliable solution.
#
# In conclusion, the world of Amazon devices and accessories offers a plethora of options to enhance your daily life. Choose wisely based on your needs and preferences, and enjoy the seamless integration of technology into your routine.
#
# ----------------------------------------------------------------------------------------------------
# Generated: 2026-02-20T14:41:06.875761 | Model: gpt-3.5-turbo
#
#
# ====================================================================================================
# CATEGORY 3: ENTERTAINMENT APPLIANCES
# ====================================================================================================
#
# ## Entertainment Appliances on Amazon: A Comprehensive Review
#
# In today's digital age, entertainment appliances play a crucial role in transforming our living rooms into immersive entertainment hubs. With the plethora of options available on Amazon, it can be overwhelming to choose the right product for your entertainment needs. To help you make an informed decision, we've curated a detailed review of the top products in the Entertainment Appliances category on Amazon.
#
# ### Top 3 Picks
#
# #### **Product 1: Fire TV Stick Streaming Media Player Pair Kit**
# - **Average Rating:** 5.0/5.0
# - **Total Reviews:** 6
# - **Quality Score:** 1.00/5.0
#
# **What Customers Love:**
# - Customers appreciate the seamless integration with Alexa for a hands-free experience.
# - Easy setup process and reliable performance were highlighted in multiple reviews.
#
# **Key Features:**
# - Works well with Alexa for voice-controlled operations.
# - Provides access to a wide range of streaming services and apps.
#
# **Common Complaints:**
# - Some users faced difficulties during the initial setup process.
#
# **Recommended for:** Users looking for a budget-friendly streaming device with voice control capabilities.
#
# #### **Product 2: Amazon Fire TV with 4K Ultra HD and Alexa Voice Remote (Pendant Design) | Streaming Media Player**
# - **Average Rating:** 5.0/5.0
# - **Total Reviews:** 4
# - **Quality Score:** 1.00/5.0
#
# **What Customers Love:**
# - Users praise the enhanced 4K streaming quality and the convenience of the Alexa Voice Remote.
# - Easy usability was a standout feature mentioned in multiple reviews.
#
# **Key Features:**
# - Supports 4K Ultra HD streaming for a superior viewing experience.
# - Alexa Voice Remote allows for hands-free control and navigation.
#
# **Common Complaints:**
# - Limited number of reviews available to identify common complaints.
#
# **Recommended for:** Consumers seeking a premium streaming experience with 4K resolution support.
#
# #### **Product 3: Amazon Fire TV Gaming Edition Streaming Media Player**
# - **Average Rating:** 4.67/5.0
# - **Total Reviews:** 3
# - **Quality Score:** 0.97/5.0
#
# **What Customers Love:**
# - Users appreciate the gaming capabilities and the wide variety of content available.
# - Easy usability and content accessibility were highlighted in positive reviews.
#
# **Key Features:**
# - Designed for gaming enthusiasts with access to a diverse range of games.
# - Offers a vast selection of entertainment content for varied preferences.
#
# **Common Complaints:**
# - Some users mentioned a lack of detailed instructions for setup and usage.
#
# **Recommended for:** Gamers and entertainment enthusiasts looking for a device that combines streaming and gaming functionalities.
#
# ### Key Differences
#
# When comparing the top 3 products, it's essential to consider the unique features that set them apart:
# - **Fire TV Stick Pair Kit:** Budget-friendly option with basic streaming and voice control features.
# - **Fire TV with 4K Ultra HD:** Premium choice for users seeking enhanced picture quality and Alexa integration.
# - **Fire TV Gaming Edition:** Ideal for gamers looking for a device that offers both gaming and streaming capabilities.
#
# ### Common Issues Across Products
#
# Based on customer feedback, common complaints across the products include:
# - Setup difficulties for some users.
# - Lack of detailed instructions in certain cases.
#
# While these issues may impact user experience, they are not prevalent across all reviews and can often be addressed with additional support or troubleshooting.
#
# ### Product to Avoid
#
# #### **Product to Avoid: Amazon Fire TV Gaming Edition Streaming Media Player**
# - **Average Rating:** 4.67/5.0
# - **Total Reviews:** 3
# - **Quality Score:** 0.97/5.0
# - **Negative Reviews:** 0.0%
#
# Despite its positive ratings, the Amazon Fire TV Gaming Edition may underperform due to the lack of detailed instructions provided for setup and usage. For users who prefer a more guided experience or clearer instructions, this product may not be the best fit.
#
# ### Final Recommendation
#
# After thorough analysis, the **Amazon Fire TV with 4K Ultra HD and Alexa Voice Remote** emerges as the best overall pick, offering a premium streaming experience with 4K resolution support and intuitive voice control features. For users on a budget, the **Fire TV Stick Streaming Media Player Pair Kit** provides a cost-effective solution with essential streaming and voice control capabilities. Gamers and entertainment enthusiasts can opt for the **Amazon Fire TV Gaming Edition** for a device that combines gaming and streaming functionalities.
#
# In conclusion, when choosing an entertainment appliance from Amazon, consider your specific needs and preferences to select the product that best aligns with your entertainment goals. Happy streaming!
#
# ----------------------------------------------------------------------------------------------------
# Generated: 2026-02-20T14:41:17.770934 | Model: gpt-3.5-turbo
#
#
# ====================================================================================================
# CATEGORY 4: KIDS TOYS & KIDS ENTERTAINMENT
# ====================================================================================================
#
# ## Amazon Kids Toys & Entertainment: Finding the Perfect Playmate for Your Child
#
# In the vast world of kids' toys and entertainment, finding the right product for your child can be a daunting task. With countless options available on Amazon, it's crucial to make an informed decision that suits your child's needs and preferences. Let's dive into the top products in this category and explore their features, strengths, and potential drawbacks based on real customer reviews.
#
# ### **Top 3 Products:**
#
# ### **Product 1: Fire Tablet, 7 Display, Wi-Fi, 8 GB - Includes Special Offers, Black**
# - **Average Rating:** 4.83/5.0
# - **Total Reviews:** 6
# - **Quality Score:** 0.99/5.0
# - **Sentiment Distribution:** 100.0% positive
#
# **What Customers Love:**
# - User-friendly and durable for young children.
# - Abundance of free content to keep kids entertained.
# - Suitable for educational games and watching cartoons.
#
# **Key Features:**
# - Durable design with a kid-friendly case.
# - Ample free content for entertainment and education.
# - Suitable for young children with age-appropriate features.
#
# **Common Complaints:**
# - Some users found the device cumbersome and not kid-friendly.
# - A few reported issues with responsiveness and speed.
# - Comparison to other brands like Apple for performance.
#
# **Who Should Buy This Product:**
# Parents looking for a durable, affordable tablet with ample content for their young children.
#
# ### **Product 2: Amazon - Kindle Voyage - 4GB - Wi-Fi + 3G - Black**
# - **Average Rating:** 4.6/5.0
# - **Total Reviews:** 15
# - **Quality Score:** 0.96/5.0
# - **Sentiment Distribution:** 93.3% positive
#
# **What Customers Love:**
# - Suitable for reading ebooks and basic web browsing.
# - Easy setup and reasonable pricing.
# - Good for both reading and web surfing.
#
# **Key Features:**
# - Great for reading and browsing with a clear display.
# - Easy to set up and use for various tasks.
# - Reasonable pricing compared to similar devices.
#
# **Common Complaints:**
# - Some users experienced slowdowns due to popups.
# - Limited app selection and restrictions on downloads.
# - Issues with durability and malfunction after minor accidents.
#
# **Who Should Buy This Product:**
# Individuals seeking a reliable e-reader with basic web browsing capabilities at a reasonable price.
#
# ### **Product 3: Certified Refurbished Amazon Fire TV (Previous Generation - 1st)**
# - **Average Rating:** 4.33/5.0
# - **Total Reviews:** 3
# - **Quality Score:** 0.95/5.0
# - **Sentiment Distribution:** 100.0% positive
#
# **What Customers Love:**
# - Good for basic functions like email and web browsing.
# - Easy setup and use with reasonable pricing.
# - Suggested as a replacement for older devices.
#
# **Key Features:**
# - Suitable for essential tasks like email and web browsing.
# - Easy to set up and use as a replacement device.
# - Reasonably priced for a refurbished model.
#
# **Common Complaints:**
# - Similar issues with popup interruptions and slow performance.
# - Limited app availability and restrictions on usage.
# - Mixed reviews on overall satisfaction and usability.
#
# **Who Should Buy This Product:**
# Users looking for an affordable, refurbished streaming device for basic entertainment needs.
#
# ### **Key Differences:**
# - **Fire Tablet:** Ideal for young children with educational content and durable design.
# - **Kindle Voyage:** Suited for reading enthusiasts with basic web capabilities.
# - **Fire TV:** A budget-friendly option for streaming content with refurbished quality.
#
# ### **Common Issues Across Products:**
# - Slow performance due to popups.
# - Limited app selection and download restrictions.
# - Durability concerns with minor accidents.
#
# ### **Product to Avoid: Fire Tablet, 7 Display, Wi-Fi, 8 GB - Includes Special Offers, Magenta**
# - **Average Rating:** 4.45/5.0
# - **Total Reviews:** 10,751
# - **Quality Score:** 0.93/5.0
# - **Negative Reviews:** 3.0%
#
# **Common Complaints:**
# - Slow performance and popup interruptions.
# - Limited app selection and download restrictions.
# - Issues with device durability and customer service.
#
# **Why to Avoid:**
# This product underperforms due to consistent complaints about performance, limited functionality, and durability issues, making it less suitable for children's entertainment needs.
#
# ### **Final Recommendation:**
# For a well-rounded choice in kids' entertainment, the **Fire Tablet, 7 Display, Wi-Fi, 8 GB - Includes Special Offers, Black** stands out as the best overall pick. It offers a balance of content, durability, and user-friendly features for young users. However, if you prioritize reading and browsing, the **Amazon - Kindle Voyage** is a suitable alternative. For budget-conscious buyers, the **Certified Refurbished Amazon Fire TV** provides a cost-effective streaming solution.
#
# When choosing a product from Amazon's Kids Toys & Entertainment category, consider your child's interests, age, and intended use to make the best decision. Each product has its strengths and weaknesses, so weigh your options carefully based on your specific needs. Happy shopping and may your child's playtime be filled with joy and learning!
#
# ----------------------------------------------------------------------------------------------------
# Generated: 2026-02-20T14:41:28.310241 | Model: gpt-3.5-turbo
#
#
# ====================================================================================================
# CATEGORY 5: BATTERIES AND HOUSEHOLD ESSENTIALS
# ====================================================================================================
#
# ## Batteries and Household Essentials: Amazon's Reliable Picks
#
# In today's digital age, batteries are a household essential, powering everything from remote controls to flashlights. With the myriad of options available, it can be challenging to find the right balance between quality and affordability. Amazon's **AmazonBasics AA and AAA Performance Alkaline Batteries** have gained popularity among consumers looking for reliable power sources at a reasonable price.
#
# ### **AmazonBasics AA Performance Alkaline Batteries (48 Count)**
#
# **Average Rating:** 4.42/5.0
# **Total Reviews:** 3,395
# **Quality Score:** 0.89/5.0
# **Sentiment Distribution:** 84.9% positive, 10.2% negative, 4.8% neutral
#
# #### What Customers Love:
# - "Bulk is always the less expensive way to go for products like these."
# - "Well if you are looking for cheap non-rechargeable batteries that last quite a while then these are perfect."
# - "Nothing more to say."
#
# #### Key Features and Strengths:
# - Affordable option for everyday power needs
# - Good performance for the price point
#
# #### Common Complaints:
# - "Battery life is much poorer compared to name brands like Energizer and Duracell."
# - "Fail in a short time on items like wireless thermometers and wall clocks."
# - "Changing is required within a month."
#
# #### Who Should Buy This Product?
# Consumers on a budget looking for basic, short-term power solutions may find these batteries suitable for their needs.
#
# ### **AmazonBasics AAA Performance Alkaline Batteries (36 Count)**
#
# **Average Rating:** 4.4/5.0
# **Total Reviews:** 7,457
# **Quality Score:** 0.88/5.0
# **Sentiment Distribution:** 84.6% positive, 10.8% negative, 4.6% neutral
#
# #### What Customers Love:
# - "Seem to work as well as name brand batteries at a much better price."
# - "Well they are not Duracell but for the price I am happy."
# - "Bulk is always the less expensive way to go."
#
# #### Key Features and Strengths:
# - Cost-effective option for powering various devices
# - Comparable performance to higher-priced brands
#
# #### Common Complaints:
# - "Did not last anywhere near as long as Duracell."
# - "Do not last long at all, very cheap batteries."
# - "Seemed to not last as long as other name brand names."
#
# #### Who Should Buy This Product?
# Shoppers seeking a budget-friendly alternative to premium battery brands may find these AAA batteries to be a suitable choice for everyday use.
#
# ### **Key Differences**
#
# - **AmazonBasics AA Batteries**: Ideal for short-term, cost-effective use, but may not offer the longevity of premium brands.
# - **AmazonBasics AAA Batteries**: A budget-friendly option that provides decent performance for everyday needs but may fall short in longevity compared to top-tier brands.
#
# ### **Common Issues Across Products**
#
# - **Short Lifespan**: Some users reported that the batteries did not last as long as premium brands like Duracell, especially in high-drain devices.
# - **Inconsistent Performance**: Complaints about varying battery life across different devices were noted, indicating potential quality control issues.
#
# ### **Product to Avoid: AmazonBasics AAA Performance Alkaline Batteries (36 Count)**
#
# **Average Rating:** 4.4/5.0
# **Total Reviews:** 7,457
# **Quality Score:** 0.88/5.0
# **Negative Reviews:** 10.8%
#
# #### Common Complaints:
# - "Failed to match the longevity of premium brands like Duracell."
# - "Battery life was lacking in various devices."
# - "Significantly shorter lifespan compared to other name brands."
#
# **Why to Avoid:** Based on user feedback, these batteries may not provide the longevity and reliability expected, especially for high-drain devices.
#
# ### **Final Recommendation**
#
# For an overall reliable choice in the Batteries and Household Essentials category, the **AmazonBasics AA Performance Alkaline Batteries (48 Count)** stand out as a cost-effective option for basic power needs. However, for those looking for a balance between affordability and performance, the **AmazonBasics AAA Performance Alkaline Batteries (36 Count)** serve as a suitable alternative.
#
# In conclusion, while Amazon's batteries offer budget-friendly solutions, consumers should consider their specific needs and usage patterns when selecting between these options. Remember, quality and longevity may vary based on the device and usage scenario.
#
# ----------------------------------------------------------------------------------------------------
# Generated: 2026-02-20T14:41:39.354729 | Model: gpt-3.5-turbo

# %% [markdown]
# ## 10. Save Summaries to Files

# %%
from pathlib import Path

# Create output directory one level above notebooks/
output_dir = Path('../generated_summaries')
output_dir.mkdir(parents=True, exist_ok=True)

print("Saving summaries...")
print()

# Save each summary as a separate file
for summary in generated_summaries:
    # Create filename (sanitize category name)
    filename = (
        summary['category']
        .lower()
        .replace(' ', '_')
        .replace('&', 'and')
    )

    filepath = output_dir / f"{filename}.txt"

    # Write to file
    with open(filepath, 'w', encoding='utf-8') as f:
        f.write(f"# {summary['category']}\n")
        f.write(f"# Generated: {summary['generated_at']}\n")
        f.write(f"# Model: {summary['model']} (temperature: {summary['temperature']})\n")
        f.write("\n" + "="*100 + "\n\n")
        f.write(summary['summary'])

    print(f"  ✓ Saved: {filepath.resolve()}")

print()
print(f"✓ All summaries saved to '{output_dir.resolve()}/'")
# Out:
# Saving summaries...
#
#   ✓ Saved: C:\Users\yogan\Documents\JupyterNotebook_ironhack\Bootcamp\week_06_02_project\project_nlp_automated_customers_reviews\generated_summaries\computers_and_electronics.txt
#   ✓ Saved: C:\Users\yogan\Documents\JupyterNotebook_ironhack\Bootcamp\week_06_02_project\project_nlp_automated_customers_reviews\generated_summaries\amazon_devices_and_accessories.txt
#   ✓ Saved: C:\Users\yogan\Documents\JupyterNotebook_ironhack\Bootcamp\week_06_02_project\project_nlp_automated_customers_reviews\generated_summaries\entertainment_appliances.txt
#   ✓ Saved: C:\Users\yogan\Documents\JupyterNotebook_ironhack\Bootcamp\week_06_02_project\project_nlp_automated_customers_reviews\generated_summaries\kids_toys_and_kids_entertainment.txt
#   ✓ Saved: C:\Users\yogan\Documents\JupyterNotebook_ironhack\Bootcamp\week_06_02_project\project_nlp_automated_customers_reviews\generated_summaries\batteries_and_household_essentials.txt
#
# ✓ All summaries saved to 'C:\Users\yogan\Documents\JupyterNotebook_ironhack\Bootcamp\week_06_02_project\project_nlp_automated_customers_reviews\generated_summaries/'

# %% [markdown]
# ## 11. Save All Summaries as Single Document

# %%
from pathlib import Path
from datetime import datetime

# Define output directory one level above notebooks/
output_dir = Path('../generated_summaries')
output_dir.mkdir(parents=True, exist_ok=True)

# Save as a single combined document
combined_filepath = output_dir / "all_category_summaries.txt"

with open(combined_filepath, 'w', encoding='utf-8') as f:
    f.write("# Amazon Product Category Reviews\n")
    f.write(f"# Generated: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
    f.write(f"# Model: {MODEL}\n")
    f.write("\n" + "="*100 + "\n\n")
    
    for i, summary in enumerate(generated_summaries, 1):
        f.write(f"\n\n{'='*100}\n")
        f.write(f"CATEGORY {i}: {summary['category'].upper()}\n")
        f.write(f"{'='*100}\n\n")
        f.write(summary['summary'])
        f.write("\n\n")

print(f"✓ Combined document saved: {combined_filepath.resolve()}")
# Out:
# ✓ Combined document saved: C:\Users\yogan\Documents\JupyterNotebook_ironhack\Bootcamp\week_06_02_project\project_nlp_automated_customers_reviews\generated_summaries\all_category_summaries.txt

# %% [markdown]
# ## 12. Save Summaries as JSON

# %%
from pathlib import Path
import json

# Define output directory one level above notebooks/
output_dir = Path('../generated_summaries')
output_dir.mkdir(parents=True, exist_ok=True)

# Save as JSON for easy integration with web apps
json_filepath = output_dir / "summaries.json"

with open(json_filepath, 'w', encoding='utf-8') as f:
    json.dump(generated_summaries, f, indent=2, ensure_ascii=False)

print(f"✓ JSON file saved: {json_filepath.resolve()}")
# Out:
# ✓ JSON file saved: C:\Users\yogan\Documents\JupyterNotebook_ironhack\Bootcamp\week_06_02_project\project_nlp_automated_customers_reviews\generated_summaries\summaries.json
