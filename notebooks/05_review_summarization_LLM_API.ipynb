# %% [markdown]
# ## 1. Import Libraries

# %%
import json
import os
from openai import OpenAI
from dotenv import load_dotenv
from datetime import datetime
import time
from pathlib import Path

# %% [markdown]
# ## 2. Configure OpenAI API Key

# %%
# Resolve project root (one level above notebooks/)
project_root = Path().resolve().parent

# Load .env explicitly
load_dotenv(project_root / ".env")

# Fetch API key
api_key = os.getenv("OPENAI_API_KEY")

if not api_key:
    raise ValueError("OPENAI_API_KEY not found in .env")

print("API key loaded successfully")

# Initialize OpenAI client
client = OpenAI(api_key=api_key)

print("OpenAI client initialized")
# Out:
# API key loaded successfully
# OpenAI client initialized

# %% [markdown]
# ## 3. Load Product Summary Data

# %%
import json

with open('../datasets/processed/product_summary_data.json',
          'r',
          encoding='utf-8') as f:
    summary_data = json.load(f)

print(f"✓ Loaded data for {len(summary_data)} categories")
print("\nCategories:")

for cat_data in summary_data:
    category = cat_data['category']
    n_products = len(cat_data.get('top_products',
                                  cat_data.get('top_3_products', [])))
    print(f"  - {category}: {n_products} products")
# Out:
# ✓ Loaded data for 5 categories
#
# Categories:
#   - Computers and electronics: 3 products
#   - Amazon devices & accessories: 3 products
#   - Entertainment Appliances: 3 products
#   - Kids Toys & kids entertainment: 3 products
#   - Batteries and household essentials: 2 products

# %% [markdown]
# ## 4. Helper Functions for Prompt Generation

# %%
#This function formats product details into readable text for the LLM.
def format_product_info(product, rank):
    """
    Format product information for the prompt.
    """
    info = f"""
Product {rank}: {product['name']}
- Average Rating: {product['avg_rating']}/5.0
- Total Reviews: {product['total_reviews']:,}
- Quality Score: {product['quality_score']:.2f}/5.0
- Sentiment Distribution: {product['positive_pct']:.1f}% positive, {product['negative_pct']:.1f}% negative, {product['neutral_pct']:.1f}% neutral
"""
    
    # Add sample positive reviews
    if product.get('positive_reviews'):
        info += "\nPositive Review Examples:\n"
        for i, review in enumerate(product['positive_reviews'][:3], 1):
            info += f"  {i}. \"{review}\"\n"
    
    # Add sample negative reviews
    if product.get('negative_reviews'):
        info += "\nNegative Review Examples:\n"
        for i, review in enumerate(product['negative_reviews'][:3], 1):
            info += f"  {i}. \"{review}\"\n"
    
    return info


def format_worst_product_info(product):
    """
    Format worst product information for the prompt.
    """
    info = f"""
Product to Avoid: {product['name']}
- Average Rating: {product['avg_rating']}/5.0
- Total Reviews: {product['total_reviews']:,}
- Quality Score: {product['quality_score']:.2f}/5.0
- Negative Reviews: {product['negative_pct']:.1f}%
"""
    
    if product.get('negative_reviews'):
        info += "\nCommon Complaints:\n"
        for i, review in enumerate(product['negative_reviews'][:5], 1):
            info += f"  {i}. \"{review}\"\n"
    
    return info


def create_summarization_prompt(category_data):
    """
    Create a comprehensive prompt for ChatGPT to generate a meta-review.
    """
    category = category_data['category']
    top_products = category_data.get('top_products', category_data.get('top_3_products', []))
    worst_product = category_data.get('worst_product')
    
    # Handle category metadata if present
    metadata = category_data.get('category_metadata', {})
    total_products = metadata.get('total_products', len(top_products))
    top_label = metadata.get('top_label', f'Top {len(top_products)}')
    
    prompt = f"""You are a professional product reviewer writing for a consumer electronics blog. Write a comprehensive, engaging article about products in the {category} category on Amazon.

# Article Requirements:
1. Write in a conversational, helpful tone (like Wirecutter or The Verge)
2. Be specific and cite actual review examples
3. Compare and contrast the products clearly
4. Provide actionable recommendations
5. Length: 600-800 words

# Structure:
## Introduction
- Brief overview of the {category} category
- Why these products matter to consumers

## {top_label}
"""
    
    # Add each product
    for i, product in enumerate(top_products, 1):
        prompt += format_product_info(product, i)
        prompt += "\n"
    
    prompt += """
### For Each Product:
- Summarize what customers love (based on positive reviews)
- Highlight key features and strengths
- Mention common complaints (based on negative reviews)
- Who should buy this product?

## Key Differences
- Create a clear comparison highlighting what makes each product unique
- Help readers choose based on their needs

## Common Issues Across Products
- Aggregate the top complaints mentioned in negative reviews
- Provide context and severity of each issue
"""
    
    # Add worst product if present
    if worst_product:
        prompt += "\n## Product to Avoid\n"
        prompt += format_worst_product_info(worst_product)
        prompt += "\n- Explain why this product underperforms based on the complaints\n"
    else:
        prompt += "\n## Note"
        if total_products <= 3:
            prompt += f"\n- This category has limited options ({total_products} products)\n"
            prompt += "- All available products are included above\n"
        else:
            prompt += "\n- All products in this category perform reasonably well\n"
    
    prompt += """
## Final Recommendation
- Provide a clear "best overall" pick
- Suggest "best value" or "best for specific use case" alternatives
- End with a confident recommendation

# Writing Guidelines:
- Use direct quotes from actual reviews (provided above)
- Be balanced - mention both pros and cons
- Use headers and bullet points for readability
- Write product names in bold on first mention
- Include specific numbers (ratings, review counts) to build credibility
- Avoid marketing language - be honest and helpful
"""
    
    return prompt

print("✓ Helper functions defined")
# Out:
# ✓ Helper functions defined

# %% [markdown]
# ## 6. Test Prompt Generation (Optional)

# %%
# Preview the prompt for the first category
test_prompt = create_summarization_prompt(summary_data[0])

print("="*100)
print("SAMPLE PROMPT FOR FIRST CATEGORY")
print("="*100)
print(test_prompt[:2000])  # Show first 2000 characters
print("\n... (truncated for display) ...\n")
print("="*100)
print(f"Full prompt length: {len(test_prompt)} characters")
# Out:
# ====================================================================================================
# SAMPLE PROMPT FOR FIRST CATEGORY
# ====================================================================================================
# You are a professional product reviewer writing for a consumer electronics blog. Write a comprehensive, engaging article about products in the Computers and electronics category on Amazon.
#
# # Article Requirements:
# 1. Write in a conversational, helpful tone (like Wirecutter or The Verge)
# 2. Be specific and cite actual review examples
# 3. Compare and contrast the products clearly
# 4. Provide actionable recommendations
# 5. Length: 600-800 words
#
# # Structure:
# ## Introduction
# - Brief overview of the Computers and electronics category
# - Why these products matter to consumers
#
# ## Top 3
#
# Product 1: Fire Tablet, 7 Display, Wi-Fi, 8 GB - Includes Special Offers, Black
# - Average Rating: 4.67/5.0
# - Total Reviews: 15
# - Quality Score: 1.05/5.0
# - Sentiment Distribution: 100.0% positive, 0.0% negative, 0.0% neutral
#
# Positive Review Examples:
#   1. "I initially had trouble deciding between the paperwhite and the voyage because reviews more or less said the same thing: the paperwhite is great, but if you have spending money, go for the voyage.Fortunately, I had friends who owned each, so I ended up buying the paperwhite on this basis: both models now have 300 ppi, so the 80 dollar jump turns out pricey the voyage's page press isn't always sensitive, and if you are fine with a specific setting, you don't need auto light adjustment).It's been a week and I am loving my paperwhite, no regrets! The touch screen is receptive and easy to use, and I keep the light at a specific setting regardless of the time of day. (In any case, it's not hard to change the setting either, as you'll only be changing the light level at a certain time of day, not every now and then while reading).Also glad that I went for the international shipping option with Amazon. Extra expense, but delivery was on time, with tracking, and I didnt need to worry about customs, which I may have if I used a third party shipping service."
#   2. "Allow me to preface this with a little history. I am (was) a casual reader who owned a
#
# ... (truncated for display) ...
#
# ====================================================================================================
# Full prompt length: 12324 characters

# %% [markdown]
# ## 7. Generate Summaries with ChatGPT

# %%
def generate_summary(category_data, model="gpt-3.5-turbo", temperature=0.7):
    """
    Generate a summary article for a category using ChatGPT.
    
    Args:
        category_data: Dictionary containing category and product information
        model: OpenAI model to use ("gpt-3.5-turbo" or "gpt-4" or "gpt-4-turbo")
        temperature: Creativity level (0.0-1.0, higher = more creative)
    
    Returns:
        Generated article text
    """
    category = category_data['category']
    print(f"\nGenerating summary for: {category}...")
    
    # Create the prompt
    prompt = create_summarization_prompt(category_data)
    
    try:
        # Call ChatGPT API
        response = client.chat.completions.create(
            model=model,
            messages=[
                {
                    "role": "system",
                    "content": "You are an expert product reviewer who writes honest, detailed, and helpful reviews for consumers. You analyze customer feedback to provide balanced recommendations."
                },
                {
                    "role": "user",
                    "content": prompt
                }
            ],
            temperature=temperature,
            max_tokens=2000  # Adjust based on desired article length
        )
        
        summary = response.choices[0].message.content
        
        # Get token usage info
        usage = response.usage
        print(f"  ✓ Generated ({usage.total_tokens} tokens: {usage.prompt_tokens} prompt + {usage.completion_tokens} completion)")
        
        return summary
        
    except Exception as e:
        print(f"  ✗ Error: {str(e)}")
        return f"Error generating summary for {category}: {str(e)}"


print("✓ Summary generation function defined")
# Out:
# ✓ Summary generation function defined

# %% [markdown]
# ## 8. Generate Summaries for All Categories

# %%
# Configuration
MODEL = "gpt-3.5-turbo"  # Options: "gpt-3.5-turbo" (cheapest) or "gpt-4" (best quality)
TEMPERATURE = 0.7  # 0.0 = more focused, 1.0 = more creative
DELAY_BETWEEN_CALLS = 2  # Seconds to wait between API calls (to avoid rate limits)

print("="*100)
print("GENERATING SUMMARIES FOR ALL CATEGORIES")
print("="*100)
print(f"Model: {MODEL}")
print(f"Temperature: {TEMPERATURE}")
print(f"Categories to process: {len(summary_data)}")
print()

# Store all generated summaries
generated_summaries = []

# Generate summary for each category
for i, category_data in enumerate(summary_data, 1):
    category = category_data['category']
    
    print(f"[{i}/{len(summary_data)}] Processing: {category}")
    
    # Generate the summary
    summary_text = generate_summary(
        category_data=category_data,
        model=MODEL,
        temperature=TEMPERATURE
    )
    
    # Store the result
    generated_summaries.append({
        'category': category,
        'summary': summary_text,
        'generated_at': datetime.now().isoformat(),
        'model': MODEL,
        'temperature': TEMPERATURE
    })
    
    # Wait before next API call (avoid rate limits)
    if i < len(summary_data):
        time.sleep(DELAY_BETWEEN_CALLS)

print()
print("="*100)
print(f"✓ COMPLETED: Generated {len(generated_summaries)} summaries")
print("="*100)
# Out:
# ====================================================================================================
# GENERATING SUMMARIES FOR ALL CATEGORIES
# ====================================================================================================
# Model: gpt-3.5-turbo
# Temperature: 0.7
# Categories to process: 5
#
# [1/5] Processing: Computers and electronics
#
# Generating summary for: Computers and electronics...
#   ✓ Generated (3959 tokens: 2915 prompt + 1044 completion)
# [2/5] Processing: Amazon devices & accessories
#
# Generating summary for: Amazon devices & accessories...
#   ✓ Generated (3214 tokens: 2221 prompt + 993 completion)
# [3/5] Processing: Entertainment Appliances
#
# Generating summary for: Entertainment Appliances...
#   ✓ Generated (1874 tokens: 987 prompt + 887 completion)
# [4/5] Processing: Kids Toys & kids entertainment
#
# Generating summary for: Kids Toys & kids entertainment...
#   ✓ Generated (2752 tokens: 1588 prompt + 1164 completion)
# [5/5] Processing: Batteries and household essentials
#
# Generating summary for: Batteries and household essentials...
#   ✓ Generated (2034 tokens: 1244 prompt + 790 completion)
#
# ====================================================================================================
# ✓ COMPLETED: Generated 5 summaries
# ====================================================================================================

# %% [markdown]
# ## 9. Display Generated Summaries

# %%
# Display all generated summaries
for i, summary in enumerate(generated_summaries, 1):
    print("\n" + "="*100)
    print(f"CATEGORY {i}: {summary['category'].upper()}")
    print("="*100)
    print()
    print(summary['summary'])
    print()
    print("-"*100)
    print(f"Generated: {summary['generated_at']} | Model: {summary['model']}")
    print()
# Out:
# ====================================================================================================
# CATEGORY 1: COMPUTERS AND ELECTRONICS
# ====================================================================================================
#
# ## Computers and Electronics on Amazon: A Comprehensive Review
#
# In today's tech-savvy world, consumers are constantly on the lookout for the latest and greatest in computers and electronics. With the vast array of options available on Amazon, it can be overwhelming to find the right products that suit your needs. In this article, we'll dive into the top three products in the Computers and Electronics category on Amazon, highlighting their features, pros, cons, and customer feedback to help you make an informed decision.
#
# ## Top 3 Products:
#
# ### **Fire Tablet, 7 Display, Wi-Fi, 8 GB - Includes Special Offers, Black**
# - **Average Rating**: 4.67/5.0
# - **Total Reviews**: 15
# - **Quality Score**: 1.05/5.0
#
# #### What Customers Love:
# - Customers appreciate the responsiveness and ease of use of the touch screen.
# - Reading on the Fire Tablet is comfortable and doesn't strain the eyes like some other devices.
# - International shipping options from Amazon ensure timely delivery without customs hassles.
#
# #### Key Features and Strengths:
# - Receptive touch screen for easy navigation.
# - Comfortable reading experience without eye strain.
# - International shipping options for hassle-free delivery.
#
# #### Common Complaints:
# - Limited storage capacity for those with larger digital libraries.
# - Some users experienced issues with app compatibility.
#
# #### Who Should Buy This Product:
# The Fire Tablet is ideal for casual readers and users looking for a budget-friendly device for reading and basic entertainment.
#
# ### **Expanding Accordion File Folder Plastic Portable Document Organizer Letter Size**
# - **Average Rating**: 5.0/5.0
# - **Total Reviews**: 9
# - **Quality Score**: 1.00/5.0
#
# #### What Customers Love:
# - The expandable bottom allows for ample storage capacity.
# - Sturdy construction ensures durability for long-term use.
#
# #### Key Features and Strengths:
# - Expanding bottom for increased storage capacity.
# - Sturdy and durable plastic construction.
#
# #### Common Complaints:
# - No notable negative reviews mentioned.
#
# #### Who Should Buy This Product:
# The Accordion File Folder is perfect for individuals looking to organize and store documents efficiently in a durable and portable folder.
#
# ### **Certified Refurbished Amazon Fire TV with Alexa Voice Remote**
# - **Average Rating**: 5.0/5.0
# - **Total Reviews**: 4
# - **Quality Score**: 1.00/5.0
#
# #### What Customers Love:
# - Users appreciate the upgrade in features from previous versions.
# - Seamless integration with the Alexa Voice Remote for enhanced user experience.
#
# #### Key Features and Strengths:
# - Upgraded features for improved performance.
# - Integration with Alexa Voice Remote for enhanced functionality.
#
# #### Common Complaints:
# - Some users found the price to be on the higher side for the features offered.
#
# #### Who Should Buy This Product:
# The Certified Refurbished Amazon Fire TV is a great choice for users looking for an upgraded streaming experience with enhanced features and Alexa integration.
#
# ## Key Differences:
#
# - The Fire Tablet is best suited for casual readers and budget-conscious users, while the Certified Refurbished Amazon Fire TV caters to those looking for an enhanced streaming experience.
# - The Accordion File Folder is ideal for organization and storage needs, offering durability and portability.
#
# ## Common Issues Across Products:
#
# - Some users mentioned limited storage capacity as a concern for the Fire Tablet.
# - Price sensitivity was a common theme among negative reviews for the Certified Refurbished Amazon Fire TV.
# - No significant complaints were mentioned for the Accordion File Folder.
#
# ## Product to Avoid:
#
# ### **Oem Amazon Kindle Power Usb Adapter Wall Travel Charger Fire/dx/+micro Usb Cable**
# - **Average Rating**: 1.0/5.0
# - **Total Reviews**: 4
# - **Quality Score**: 0.08/5.0
#
# #### Common Complaints:
# - Users expressed frustration over the additional cost of the charger, which they felt should have been included with the device.
# - Some customers found the product description misleading and the pricing unreasonable.
#
# Based on customer feedback, the Oem Amazon Kindle Power Usb Adapter Wall Travel Charger is a product to avoid due to concerns over pricing and value.
#
# ## Final Recommendation:
#
# After analyzing the top products in the Computers and Electronics category on Amazon, the **Fire Tablet** stands out as the best overall pick for its combination of affordability, functionality, and positive user feedback. For those seeking a budget-friendly option for reading and entertainment, the Fire Tablet is a solid choice.
#
# For users looking for enhanced streaming capabilities, the **Certified Refurbished Amazon Fire TV** offers upgraded features and Alexa integration, making it a great value for those willing to invest in a premium streaming experience.
#
# Lastly, the **Accordion File Folder** is recommended for individuals looking to efficiently organize and store documents in a durable and portable folder without breaking the bank.
#
# In conclusion, whether you're a casual reader, a binge-watcher, or an organization enthusiast, Amazon's Computers and Electronics category has something for everyone. Make an informed decision based on your specific needs and budget to find the perfect product to enhance your digital lifestyle.
#
# ----------------------------------------------------------------------------------------------------
# Generated: 2026-02-20T18:19:34.108221 | Model: gpt-3.5-turbo
#
#
# ====================================================================================================
# CATEGORY 2: AMAZON DEVICES & ACCESSORIES
# ====================================================================================================
#
# ## Amazon Devices & Accessories: Enhancing Your Smart Home Experience
#
# In today's tech-savvy world, Amazon devices and accessories play a crucial role in transforming your living space into a smart home. From voice-activated assistants to protective cases, these products offer convenience, entertainment, and style.
#
# ### **Top 3 Picks**
#
# ### **1. **Echo (Black)**
# - **Average Rating:** 5.0/5.0
# - **Total Reviews:** 3
# - **Quality Score:** 1.00/5.0
# - **Sentiment:** 100.0% positive
#
# **What Customers Love:**
# - Seamless voice recognition for tasks like setting timers and playing music
# - Impressive sound quality, especially on the full-size Echo
# - Fun and useful conversation starter
#
# **Key Features:**
# - Voice-controlled smart speaker with Alexa integration
# - Prime music streaming and radio station playback
# - Excellent sound quality for music enthusiasts
#
# **Common Complaints:**
# - Relies on Bing search engine for queries
# - Limited multi-device reminders and alarms
# - Some users find it unnecessary but enjoyable
#
# **Who Should Buy:**
# Ideal for music lovers, smart home enthusiasts, and those looking for a fun tech gadget.
#
# ### **2. **Certified Refurbished Amazon Echo**
# - **Average Rating:** 5.0/5.0
# - **Total Reviews:** 7
# - **Quality Score:** 1.00/5.0
# - **Sentiment:** 100.0% positive
#
# **What Customers Love:**
# - Seamless integration with Google calendar and notifications
# - Durable build with options for stands and mounts
# - Clear picture on the monitor for easy setup
#
# **Key Features:**
# - Refurbished Echo with all original functionalities
# - Compatible with various accessories for customization
# - Informative and user-friendly Alexa assistant
#
# **Common Complaints:**
# - Messaging feature lacks iPhone integration
# - Requires additional accessories for protection
# - Limited availability during peak seasons
#
# **Who Should Buy:**
# Great for users seeking a cost-effective smart home device with added customization options.
#
# ### **3. **Amazon Fire Hd 6 Standing Protective Case (4th Generation - 2014 Release), Cayenne Red**
# - **Average Rating:** 4.83/5.0
# - **Total Reviews:** 6
# - **Quality Score:** 0.99/5.0
# - **Sentiment:** 100.0% positive
#
# **What Customers Love:**
# - Stylish and protective case design
# - Easy installation with mobile phone support
# - Suitable for standing up the device for hands-free use
#
# **Key Features:**
# - Specifically designed for Amazon Fire HD 6 (4th Gen)
# - Durable material for enhanced protection
# - Stylish color options to suit personal preferences
#
# **Common Complaints:**
# - Limited availability for newer device models
# - Some users find it unnecessary for their usage
# - Minor compatibility issues reported by a few customers
#
# **Who Should Buy:**
# Ideal for Amazon Fire HD 6 owners looking to protect and personalize their devices.
#
# ### **Key Differences**
#
# - **Echo vs. Certified Refurbished Echo:** The Echo offers premium sound quality, while the Certified Refurbished Echo is a budget-friendly alternative with similar functionalities.
# - **Echo vs. Amazon Fire Hd 6 Standing Protective Case:** While the Echo is a voice-controlled speaker, the Fire HD 6 case provides protection and style for your tablet.
#
# ### **Common Issues Across Products**
#
# - **Limited Multi-Device Functionality:** Echo users often wish for better multi-device reminders and alarms.
# - **Accessory Availability:** Some customers face challenges in finding suitable accessories for their devices.
#
# ### **Product to Avoid: Amazon Tap Smart Assistant Alexaenabled (Black) Brand New**
# - **Average Rating:** 4.0/5.0
# - **Total Reviews:** 8
# - **Quality Score:** 0.84/5.0
# - **Negative Reviews:** 12.5%
#
# **Common Complaints:**
# - Difficulty in setting up and using the device
# - Intrusive product suggestions by the assistant
#
# **Why to Avoid:**
# The Amazon Tap Smart Assistant underperforms due to setup issues and unwanted product promotions, leading to user frustration.
#
# ### **Final Recommendation**
#
# For the best overall smart home experience, the **Echo (Black)** stands out for its exceptional sound quality and versatile functionalities. If you're looking for a budget-friendly option, the **Certified Refurbished Echo** offers great value with reliable performance. However, if you're seeking device protection and style, the **Amazon Fire Hd 6 Standing Protective Case** is a worthwhile investment.
#
# In conclusion, Amazon devices and accessories cater to a wide range of consumer needs, enhancing your daily routines with convenience and entertainment. Choose the product that aligns with your requirements and enjoy a seamless smart home experience.
#
# ----------------------------------------------------------------------------------------------------
# Generated: 2026-02-20T18:19:46.847349 | Model: gpt-3.5-turbo
#
#
# ====================================================================================================
# CATEGORY 3: ENTERTAINMENT APPLIANCES
# ====================================================================================================
#
# ## Unveiling the Best Entertainment Appliances on Amazon
#
# Welcome to the world of entertainment appliances, where streaming meets convenience. In this article, we'll dive into the top products in this category on Amazon, exploring their features, strengths, and customer feedback to help you make an informed decision.
#
# ### Top 3 Products
#
# ### **Fire TV Stick Streaming Media Player Pair Kit**
# - **Average Rating:** 5.0/5.0
# - **Total Reviews:** 6
# - **Quality Score:** 1.00/5.0
# - **Sentiment Distribution:** 100.0% positive
#
# #### What Customers Love
# - Customers appreciate the ease of use, with one reviewer recommending it for its functionality.
# - Another positive review highlights the reliability of the product for entertainment access.
#
# #### Key Features
# - Easy setup and reliable performance.
# - Access to a wide range of entertainment options.
#
# #### Common Complaints
# - Some users found the setup to be a bit of a hassle.
# - A few users reported issues with specific functions like mirror casting.
#
# #### Who Should Buy
# - Ideal for those looking for a straightforward streaming experience with access to various entertainment options.
#
# ### **Amazon Fire TV with 4K Ultra HD and Alexa Voice Remote (Pendant Design) | Streaming Media Player**
# - **Average Rating:** 5.0/5.0
# - **Total Reviews:** 4
# - **Quality Score:** 1.00/5.0
# - **Sentiment Distribution:** 100.0% positive
#
# #### What Customers Love
# - Users praise the device for its ease of use and the enhanced experience it provides.
# - The 4K Ultra HD feature is a standout for many customers.
#
# #### Key Features
# - 4K Ultra HD streaming for superior picture quality.
# - Integration with Alexa for voice-controlled convenience.
#
# #### Common Complaints
# - Limited reviews mentioned any issues, indicating a high level of customer satisfaction.
#
# #### Who Should Buy
# - Individuals seeking a premium streaming experience with high-quality visuals and voice control capabilities.
#
# ### **Amazon Fire TV Gaming Edition Streaming Media Player**
# - **Average Rating:** 4.67/5.0
# - **Total Reviews:** 3
# - **Quality Score:** 0.97/5.0
# - **Sentiment Distribution:** 100.0% positive
#
# #### What Customers Love
# - Users appreciate the device's performance and user-friendly interface.
# - The gaming edition offers a unique entertainment experience.
#
# #### Key Features
# - Gaming capabilities for added entertainment options.
# - Intuitive user interface for seamless navigation.
#
# #### Common Complaints
# - Some users desired more detailed instructions for optimal usage.
# - A few users found the device overwhelming due to the extensive content available.
#
# #### Who Should Buy
# - Gaming enthusiasts or those looking to expand their entertainment options beyond traditional streaming.
#
# ### Key Differences
#
# When comparing the **Fire TV Stick**, **Fire TV Pendant Design**, and **Fire TV Gaming Edition**, some key differences emerge:
# - The **Fire TV Stick** is ideal for straightforward streaming.
# - The **Fire TV Pendant Design** offers premium 4K streaming and voice control.
# - The **Fire TV Gaming Edition** caters to gamers and those seeking a broader entertainment experience.
#
# ### Common Issues Across Products
#
# While the products generally received positive feedback, common complaints included:
# 1. Setup hassles for some users.
# 2. Specific feature malfunctions like mirror casting.
# 3. Desire for more detailed instructions for optimal usage.
#
# ### Product to Avoid
#
# ### **Amazon Fire TV Gaming Edition Streaming Media Player**
# - **Average Rating:** 4.67/5.0
# - **Total Reviews:** 3
# - **Quality Score:** 0.97/5.0
# - **Negative Reviews:** 0.0%
#
# While this product received positive feedback overall, the lack of detailed instructions and overwhelming content could be potential drawbacks for some users.
#
# ### Final Recommendation
#
# In conclusion, the **Amazon Fire TV with 4K Ultra HD and Alexa Voice Remote (Pendant Design)** stands out as the best overall pick, offering premium features and exceptional performance. For a budget-friendly option, the **Fire TV Stick Streaming Media Player Pair Kit** is a solid choice. If you're a gaming enthusiast, the **Amazon Fire TV Gaming Edition** provides a unique entertainment experience.
#
# Choose the product that best suits your entertainment needs and elevate your streaming experience today!
#
# ----------------------------------------------------------------------------------------------------
# Generated: 2026-02-20T18:19:57.851238 | Model: gpt-3.5-turbo
#
#
# ====================================================================================================
# CATEGORY 4: KIDS TOYS & KIDS ENTERTAINMENT
# ====================================================================================================
#
# # Kids Toys & Entertainment: Amazon's Top Picks
#
# When it comes to keeping kids entertained and engaged, Amazon offers a wide range of products that cater to various interests and age groups. From tablets for educational purposes to entertainment devices, the choices are abundant. Let's dive into the top 3 products in the Kids Toys & Entertainment category on Amazon, based on customer reviews and ratings.
#
# ## Product 1: **Fire Tablet, 7 Display, Wi-Fi, 8 GB - Includes Special Offers, Black**
# - **Average Rating:** 4.83/5.0
# - **Total Reviews:** 6
# - **Quality Score:** 0.99/5.0
# - **Sentiment Distribution:** 100.0% positive, 0.0% negative, 0.0% neutral
#
# **What Customers Love:**
# - Customers praise the user-friendly interface and durability, making it perfect for kids.
# - The abundance of free content keeps children engaged and entertained.
# - Parents appreciate the educational games and cartoons available on the tablet.
#
# **Key Features:**
# - Durable with a kid-friendly case.
# - Plenty of free content.
# - Educational games and cartoons for kids.
#
# **Common Complaints:**
# - Some users find the device cumbersome and not kid-friendly.
# - Complaints about slow response time and loading content.
# - A few users experienced touch issues with the screen.
#
# **Who Should Buy This Product:**
# Parents looking for a durable and kid-friendly tablet with educational content should consider the **Fire Tablet**.
#
# ## Product 2: **Amazon - Kindle Voyage - 4GB - Wi-Fi + 3G - Black**
# - **Average Rating:** 4.6/5.0
# - **Total Reviews:** 15
# - **Quality Score:** 0.96/5.0
# - **Sentiment Distribution:** 93.3% positive, 0.0% negative, 6.7% neutral
#
# **What Customers Love:**
# - Users appreciate the tablet for email checking, web browsing, and reading ebooks.
# - The device is described as a great reader and suitable for web surfing.
# - Customers find the setup easy and the price reasonable.
#
# **Key Features:**
# - Suitable for reading ebooks and web browsing.
# - Easy setup and reasonable price.
# - Good for basic tablet functions.
#
# **Common Complaints:**
# - Some users experienced slow performance due to constant popups.
# - Issues with app downloads and mandatory credit card signup for "One Click."
# - Mixed reviews regarding the device's overall performance.
#
# **Who Should Buy This Product:**
# Families looking for a versatile tablet for reading and basic browsing activities might find the **Kindle Voyage** appealing.
#
# ## Product 3: **Certified Refurbished Amazon Fire TV (Previous Generation - 1st)**
# - **Average Rating:** 4.33/5.0
# - **Total Reviews:** 3
# - **Quality Score:** 0.95/5.0
# - **Sentiment Distribution:** 100.0% positive, 0.0% negative, 0.0% neutral
#
# **What Customers Love:**
# - Users appreciate the tablet for email checking, web browsing, and reading ebooks.
# - The device is described as a great reader and suitable for web surfing.
# - Customers find the setup easy and the price reasonable.
#
# **Key Features:**
# - Suitable for reading ebooks and web browsing.
# - Easy setup and reasonable price.
# - Good for basic tablet functions.
#
# **Common Complaints:**
# - Some users experienced slow performance due to constant popups.
# - Issues with app downloads and mandatory credit card signup for "One Click."
# - Mixed reviews regarding the device's overall performance.
#
# **Who Should Buy This Product:**
# Families looking for a versatile tablet for reading and basic browsing activities might find the **Certified Refurbished Amazon Fire TV** appealing.
#
# ## Key Differences
# - **Fire Tablet:** Ideal for kids with a user-friendly interface and educational content.
# - **Kindle Voyage:** Suitable for reading ebooks and basic browsing needs.
# - **Certified Refurbished Amazon Fire TV:** A good option for those seeking a versatile entertainment device.
#
# ## Common Issues Across Products
# - Slow performance due to popups.
# - App download issues and mandatory credit card signup.
# - Mixed reviews on overall device performance.
#
# ## Product to Avoid: **Fire Tablet, 7 Display, Wi-Fi, 8 GB - Includes Special Offers, Magenta**
# - **Average Rating:** 4.45/5.0
# - **Total Reviews:** 10,751
# - **Quality Score:** 0.93/5.0
# - **Negative Reviews:** 3.0%
#
# **Common Complaints:**
# - Slow performance and responsiveness issues.
# - App download restrictions and mandatory credit card signup.
# - Lack of kid-friendly features and insufficient product information.
#
# **Why to Avoid:**
# Based on customer complaints, the **Fire Tablet in Magenta** falls short in terms of performance, kid-friendliness, and overall user experience.
#
# ## Final Recommendation
# - **Best Overall:** The **Fire Tablet, 7 Display, Wi-Fi, 8 GB - Includes Special Offers, Black** stands out for its kid-friendly features and educational content.
# - **Best Value:** The **Kindle Voyage** offers a good balance between reading functionality and browsing capabilities.
# - **Best for Specific Use Case:** Families seeking a versatile entertainment device may find the **Certified Refurbished Amazon Fire TV** suitable.
#
# In conclusion, when choosing a product for kids' entertainment, consider factors such as durability, educational content, and ease of use. Each of the mentioned products caters to different needs, so pick the one that aligns best with your requirements.
#
# ----------------------------------------------------------------------------------------------------
# Generated: 2026-02-20T18:20:14.974669 | Model: gpt-3.5-turbo
#
#
# ====================================================================================================
# CATEGORY 5: BATTERIES AND HOUSEHOLD ESSENTIALS
# ====================================================================================================
#
# # Amazon Batteries and Household Essentials: A Comprehensive Review
#
# In today's digital age, batteries have become an indispensable household essential. From powering remote controls to children's toys, a reliable source of energy is a must. Amazon offers a range of battery products under their **Batteries and Household Essentials** category, catering to various needs and preferences of consumers.
#
# ## Top 2 Products
#
# ### **AmazonBasics AA Performance Alkaline Batteries (48 Count) - Packaging May Vary**
# - **Average Rating:** 4.42/5.0
# - **Total Reviews:** 3,395
# - **Quality Score:** 0.89/5.0
# - **Sentiment Distribution:** 84.9% positive, 10.2% negative, 4.8% neutral
#
# **Positive Review Examples:**
# - "Bulk is always the less expensive way to go for products like these."
# - "If you are looking for cheap non-rechargeable batteries that last quite a while then these are perfect."
#
# **Negative Review Examples:**
# - "The battery life is much poorer compared to name brands like Energizer and Duracell."
# - "Fail in a short time on items like wireless thermometers and wall clocks."
#
# **Who should buy this product:** Consumers looking for affordable bulk batteries for low-drain devices.
#
# ### **AmazonBasics AAA Performance Alkaline Batteries (36 Count)**
# - **Average Rating:** 4.4/5.0
# - **Total Reviews:** 7,457
# - **Quality Score:** 0.88/5.0
# - **Sentiment Distribution:** 84.6% positive, 10.8% negative, 4.6% neutral
#
# **Positive Review Examples:**
# - "Seem to work as well as name brand batteries at a much better price."
# - "Not Duracell but for the price I am happy."
#
# **Negative Review Examples:**
# - "Did not last anywhere near as long as Duracell in devices like LED candles and trail cameras."
# - "Seemed to not last as long as other name brand names."
#
# **Who should buy this product:** Budget-conscious consumers needing AAA batteries for everyday devices.
#
# ## Key Differences
#
# While both AmazonBasics AA and AAA batteries offer cost-effective solutions, the AA batteries are better suited for low-drain devices, whereas the AAA batteries may not last as long compared to premium brands in high-drain gadgets.
#
# ## Common Issues Across Products
#
# The most common complaints across both products revolve around subpar battery life compared to established brands like Duracell and Energizer, especially in higher-drain devices. Users also noted issues with early depletion in certain gadgets like thermometers and cameras.
#
# ## Product to Avoid
#
# ### **AmazonBasics AAA Performance Alkaline Batteries (36 Count)**
# - **Average Rating:** 4.4/5.0
# - **Total Reviews:** 7,457
# - **Quality Score:** 0.88/5.0
# - **Negative Reviews:** 10.8%
#
# **Common Complaints:**
# - "Do not last long at all, very cheap batteries."
# - "Underperform compared to brand-name batteries."
#
# **Reason for Underperformance:** The AmazonBasics AAA batteries fall short in longevity and performance when compared to leading brands, making them less suitable for high-drain devices.
#
# ## Final Recommendation
#
# For the best overall performance and value, the **AmazonBasics AA Performance Alkaline Batteries (48 Count)** are recommended for their affordability and decent performance in low-drain devices. However, if you require AAA batteries, consider premium brands for longer-lasting power in high-drain gadgets.
#
# In conclusion, when selecting batteries from Amazon's range of household essentials, prioritize your specific needs and usage patterns to make an informed decision that aligns with your requirements and budget.
#
# ----------------------------------------------------------------------------------------------------
# Generated: 2026-02-20T18:20:24.933600 | Model: gpt-3.5-turbo

# %% [markdown]
# ## 10. Save Summaries to Files

# %%
from pathlib import Path

# Create output directory one level above notebooks/
output_dir = Path('../generated_summaries')
output_dir.mkdir(parents=True, exist_ok=True)

print("Saving summaries...")
print()

# Save each summary as a separate file
for summary in generated_summaries:
    # Create filename (sanitize category name)
    filename = (
        summary['category']
        .lower()
        .replace(' ', '_')
        .replace('&', 'and')
    )

    filepath = output_dir / f"{filename}.txt"

    # Write to file
    with open(filepath, 'w', encoding='utf-8') as f:
        f.write(f"# {summary['category']}\n")
        f.write(f"# Generated: {summary['generated_at']}\n")
        f.write(f"# Model: {summary['model']} (temperature: {summary['temperature']})\n")
        f.write("\n" + "="*100 + "\n\n")
        f.write(summary['summary'])

    print(f"  ✓ Saved: {filepath.resolve()}")

print()
print(f"✓ All summaries saved to '{output_dir.resolve()}/'")
# Out:
# Saving summaries...
#
#   ✓ Saved: C:\Users\yogan\Documents\JupyterNotebook_ironhack\Bootcamp\week_06_02_project\project_nlp_automated_customers_reviews\generated_summaries\computers_and_electronics.txt
#   ✓ Saved: C:\Users\yogan\Documents\JupyterNotebook_ironhack\Bootcamp\week_06_02_project\project_nlp_automated_customers_reviews\generated_summaries\amazon_devices_and_accessories.txt
#   ✓ Saved: C:\Users\yogan\Documents\JupyterNotebook_ironhack\Bootcamp\week_06_02_project\project_nlp_automated_customers_reviews\generated_summaries\entertainment_appliances.txt
#   ✓ Saved: C:\Users\yogan\Documents\JupyterNotebook_ironhack\Bootcamp\week_06_02_project\project_nlp_automated_customers_reviews\generated_summaries\kids_toys_and_kids_entertainment.txt
#   ✓ Saved: C:\Users\yogan\Documents\JupyterNotebook_ironhack\Bootcamp\week_06_02_project\project_nlp_automated_customers_reviews\generated_summaries\batteries_and_household_essentials.txt
#
# ✓ All summaries saved to 'C:\Users\yogan\Documents\JupyterNotebook_ironhack\Bootcamp\week_06_02_project\project_nlp_automated_customers_reviews\generated_summaries/'

# %% [markdown]
# ## 11. Save All Summaries as Single Document

# %%
from pathlib import Path
from datetime import datetime

# Define output directory one level above notebooks/
output_dir = Path('../generated_summaries')
output_dir.mkdir(parents=True, exist_ok=True)

# Save as a single combined document
combined_filepath = output_dir / "all_category_summaries.txt"

with open(combined_filepath, 'w', encoding='utf-8') as f:
    f.write("# Amazon Product Category Reviews\n")
    f.write(f"# Generated: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
    f.write(f"# Model: {MODEL}\n")
    f.write("\n" + "="*100 + "\n\n")
    
    for i, summary in enumerate(generated_summaries, 1):
        f.write(f"\n\n{'='*100}\n")
        f.write(f"CATEGORY {i}: {summary['category'].upper()}\n")
        f.write(f"{'='*100}\n\n")
        f.write(summary['summary'])
        f.write("\n\n")

print(f"✓ Combined document saved: {combined_filepath.resolve()}")
# Out:
# ✓ Combined document saved: C:\Users\yogan\Documents\JupyterNotebook_ironhack\Bootcamp\week_06_02_project\project_nlp_automated_customers_reviews\generated_summaries\all_category_summaries.txt

# %%
# -----------------------------
# SAVE AS PDF (single document)
# -----------------------------

from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer
from reportlab.platypus import HRFlowable
from reportlab.lib.styles import getSampleStyleSheet
from reportlab.lib.pagesizes import letter
from reportlab.lib.units import inch
from reportlab.lib import colors

pdf_filepath = output_dir / "all_category_summaries.pdf"

doc = SimpleDocTemplate(str(pdf_filepath), pagesize=letter)
elements = []
styles = getSampleStyleSheet()

# Title
elements.append(Paragraph("Amazon Product Category Reviews", styles["Heading1"]))
elements.append(Spacer(1, 0.2 * inch))
elements.append(Paragraph(f"Generated: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}", styles["Normal"]))
elements.append(Paragraph(f"Model: {MODEL}", styles["Normal"]))
elements.append(Spacer(1, 0.3 * inch))
elements.append(HRFlowable(width="100%", thickness=1, color=colors.grey))
elements.append(Spacer(1, 0.3 * inch))

# Categories
for i, summary in enumerate(generated_summaries, 1):
    elements.append(Paragraph(
        f"CATEGORY {i}: {summary['category'].upper()}",
        styles["Heading2"]
    ))
    elements.append(Spacer(1, 0.2 * inch))
    
    elements.append(Paragraph(
        summary['summary'].replace('\n', '<br/>'),
        styles["BodyText"]
    ))
    
    elements.append(Spacer(1, 0.4 * inch))
    elements.append(HRFlowable(width="100%", thickness=0.5, color=colors.lightgrey))
    elements.append(Spacer(1, 0.3 * inch))

doc.build(elements)

print(f"✓ PDF saved: {pdf_filepath.resolve()}")
# Out:
# ✓ PDF saved: C:\Users\yogan\Documents\JupyterNotebook_ironhack\Bootcamp\week_06_02_project\project_nlp_automated_customers_reviews\generated_summaries\all_category_summaries.pdf

# %% [markdown]
# ## 12. Save Summaries as JSON

# %%
from pathlib import Path
import json

# Define output directory one level above notebooks/
output_dir = Path('../generated_summaries')
output_dir.mkdir(parents=True, exist_ok=True)

# Save as JSON for easy integration with web apps
json_filepath = output_dir / "summaries.json"

with open(json_filepath, 'w', encoding='utf-8') as f:
    json.dump(generated_summaries, f, indent=2, ensure_ascii=False)

print(f"✓ JSON file saved: {json_filepath.resolve()}")
# Out:
# ✓ JSON file saved: C:\Users\yogan\Documents\JupyterNotebook_ironhack\Bootcamp\week_06_02_project\project_nlp_automated_customers_reviews\generated_summaries\summaries.json
